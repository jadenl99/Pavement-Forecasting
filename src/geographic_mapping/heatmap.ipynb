# %%
import geopandas as gpd
import contextily as cx
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import geodatasets as gds
import pandas as pd
from shapely.geometry import Point


df = pd.read_csv('..\..\spreadsheet_data\i16WB_tag_replaced.csv')
df.head()
# Out:
#   Interstate Direction    MP From      MP To  2014 Slab ID  BY Length (ft)  \
# 0       I-16        WB  22.000000  21.997566             3           12.85
# 1       I-16        WB  21.997566  21.994286             4           17.32
# 2       I-16        WB  21.994286  21.991244             5           16.06
# 3       I-16        WB  21.991244  21.987169             6           21.52
# 4       I-16        WB  21.987169  21.982809             7           23.02
#
#   2014 2015 2016 2017 2018  Replaced  Year Replaced  Replaced and Broken  \
# 0    R    R    R    R    R       NaN            NaN                  NaN
# 1   NC   NC   NC   NC   NC       NaN            NaN                  NaN
# 2   NC   NC   NC   NC   NC       NaN            NaN                  NaN
# 3   NC   NC   NC   NC   NC       NaN            NaN                  NaN
# 4   NC   NC   NC   NC   NC       NaN            NaN                  NaN
#
#    Possibly OR  possibly_replaced_or_bridge          x          y
# 0          NaN                            1 -83.392094  32.635684
# 1          NaN                            0 -83.392129  32.635700
# 2          NaN                            0 -83.392176  32.635722
# 3          NaN                            0 -83.392220  32.635741
# 4          NaN                            0 -83.392279  32.635768

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.x, df.y), crs='EPSG:3857')
gdf.to_crs(epsg=3857, inplace=True)

# %%
fig = gdf.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
cx.add_basemap(fig)
# Out:
# c:\Users\jaden\anaconda3\envs\geo\lib\site-packages\contextily\tile.py:614: UserWarning: The inferred zoom level of 29 is not valid for the current tile provider (valid zooms: 0 - 19).
#   warnings.warn(msg)
